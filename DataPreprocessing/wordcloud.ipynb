# %%
import csv 
from wordcloud import WordCloud 
import pandas as pd

# %%
data=pd.read_csv("SPAM text message 20170820 - Data.csv",encoding='utf-8')

# %%
spam=data.loc[data["Category"]=="spam",["Message"]]

# %%
listS=[]
for i in spam.Message:
    listS.append(i)

# %%
print(type(listS[0]))
# Out:
# <class 'str'>

# %%
wordcloud = WordCloud().generate(str(listS))

# %%
import matplotlib.pyplot as plt 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
ham=data.loc[data["Category"]=="ham",["Message"]]
listH=[]
for i in ham.Message:
    listH.append(i)
    
wordcloudH = WordCloud().generate(str(listH))
plt.imshow(wordcloudH, interpolation='bilinear') 
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# https://financedata.github.io/posts/python_news_cloud_text.html
# - - -
# 여기 참조 좀 하자

# %%
wordcloud.
# Out:
# <bound method WordCloud.fit_words of <wordcloud.wordcloud.WordCloud object at 0x000001F32E0002B0>>

# %%
spam_column_list=["free","call" "text","txt","mobile","please","customer","service",
                 "message","now","stop","reply","guranted"]
